# %% [markdown]
# **item-based Collabrative filtering recommendation**

# %%
import pandas as pd

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
df = pd.read_excel("/content/online.xlsx")

# %%
print(df)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55   17,850.00  United Kingdom
# 1      2010-12-01 08:26:00       3.39   17,850.00  United Kingdom
# 2      2010-12-01 08:26:00       2.75   17,850.00  United Kingdom
# 3      2010-12-01 08:26:00       3.39   17,850.00  United Kingdom
# 4      2010-12-01 08:26:00       3.39   17,850.00  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85   12,680.00          France
# 541905 2011-12-09 12:50:00       2.10   12,680.00          France
# 541906 2011-12-09 12:50:00       4.15   12,680.00          France
# 541907 2011-12-09 12:50:00       4.15   12,680.00          France
# 541908 2011-12-09 12:50:00       4.95   12,680.00          France
#
# [541909 rows x 8 columns]

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55   17,850.00  United Kingdom
# 1 2010-12-01 08:26:00       3.39   17,850.00  United Kingdom
# 2 2010-12-01 08:26:00       2.75   17,850.00  United Kingdom
# 3 2010-12-01 08:26:00       3.39   17,850.00  United Kingdom
# 4 2010-12-01 08:26:00       3.39   17,850.00  United Kingdom

# %%
#rename the column
df.rename(columns={"StockCode": "ProductId","Description": "ProductName"}, inplace = True)

# %%
df.head()
# Out:
#   InvoiceNo ProductId                          ProductName  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55   17,850.00  United Kingdom
# 1 2010-12-01 08:26:00       3.39   17,850.00  United Kingdom
# 2 2010-12-01 08:26:00       2.75   17,850.00  United Kingdom
# 3 2010-12-01 08:26:00       3.39   17,850.00  United Kingdom
# 4 2010-12-01 08:26:00       3.39   17,850.00  United Kingdom

# %%
df.groupby('ProductName').agg(
    orders=('InvoiceNo', 'nunique'),
    quantity=('Quantity', 'sum')
).sort_values(by='orders', ascending=False).head(10)
# Out:
#                                     orders  quantity
# ProductName
# WHITE HANGING HEART T-LIGHT HOLDER    2302     35317
# REGENCY CAKESTAND 3 TIER              2169     13033
# JUMBO BAG RED RETROSPOT               2135     47363
# PARTY BUNTING                         1706     18022
# LUNCH BAG RED RETROSPOT               1607     18779
# ASSORTED COLOUR BIRD ORNAMENT         1467     36381
# SET OF 3 CAKE TINS PANTRY DESIGN      1458      7336
# PACK OF 72 RETROSPOT CAKE CASES       1334     36039
# LUNCH BAG  BLACK SKULL.               1295     12112
# NATURAL SLATE HEART CHALKBOARD        1266      9120

# %%
df_items = df.pivot_table(index='InvoiceNo', columns=['ProductName'], values='Quantity').fillna(0)

# %%
df_items.head(3)
# Out:
# ProductName  20713   4 PURPLE FLOCK DINNER CANDLES  \
# InvoiceNo
# 536365        0.00                            0.00
# 536366        0.00                            0.00
# 536367        0.00                            0.00
#
# ProductName   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536365                                 0.00                0.00
# 536366                                 0.00                0.00
# 536367                                 0.00                0.00
#
# ProductName   I LOVE LONDON MINI BACKPACK   I LOVE LONDON MINI RUCKSACK  \
# InvoiceNo
# 536365                               0.00                          0.00
# 536366                               0.00                          0.00
# 536367                               0.00                          0.00
#
# ProductName   NINE DRAWER OFFICE TIDY   OVAL WALL MIRROR DIAMANTE   \
# InvoiceNo
# 536365                           0.00                         0.00
# 536366                           0.00                         0.00
# 536367                           0.00                         0.00
#
# ProductName   RED SPOT GIFT BAG LARGE   SET 2 TEA TOWELS I LOVE LONDON   ...  \
# InvoiceNo                                                                ...
# 536365                           0.00                              0.00  ...
# 536366                           0.00                              0.00  ...
# 536367                           0.00                              0.00  ...
#
# ProductName  wrongly coded 20713  wrongly coded 23343  wrongly coded-23343  \
# InvoiceNo
# 536365                      0.00                 0.00                 0.00
# 536366                      0.00                 0.00                 0.00
# 536367                      0.00                 0.00                 0.00
#
# ProductName  wrongly marked  wrongly marked 23343  \
# InvoiceNo
# 536365                 0.00                  0.00
# 536366                 0.00                  0.00
# 536367                 0.00                  0.00
#
# ProductName  wrongly marked carton 22804  wrongly marked. 23343 in box  \
# InvoiceNo
# 536365                              0.00                          0.00
# 536366                              0.00                          0.00
# 536367                              0.00                          0.00
#
# ProductName  wrongly sold (22719) barcode  wrongly sold as sets  \
# InvoiceNo
# 536365                               0.00                  0.00
# 536366                               0.00                  0.00
# 536367                               0.00                  0.00
#
# ProductName  wrongly sold sets
# InvoiceNo
# 536365                    0.00
# 536366                    0.00
# 536367                    0.00
#
# [3 rows x 4223 columns]

# %%
def get_recommendations(df, item):
    """Generate a set of product recommendations using item-based collaborative filtering.

    Args:
        df (dataframe): Pandas dataframe containing matrix of items purchased.
        item (string): Column name for target item.

    Returns:
        recommendations (dataframe): Pandas dataframe containing product recommendations.
    """

    recommendations = df.corrwith(df[item])
    recommendations.dropna(inplace=True)
    recommendations = pd.DataFrame(recommendations, columns=['correlation']).reset_index()
    recommendations = recommendations.sort_values(by='correlation', ascending=False)

    return recommendations

# %%
recommendations = get_recommendations(df_items, 'WHITE HANGING HEART T-LIGHT HOLDER')

# %%
recommendations.head()
# Out:
#                              ProductName  correlation
# 3918  WHITE HANGING HEART T-LIGHT HOLDER         1.00
# 1478         GIN + TONIC DIET METAL SIGN         0.82
# 1241  FAIRY CAKE FLANNEL ASSORTED COLOUR         0.82
# 1072                  DOORMAT FAIRY CAKE         0.48
# 3627              TEA TIME PARTY BUNTING         0.47

# %%
recommendations = get_recommendations(df_items, 'PARTY BUNTING')
recommendations.head()
# Out:
#                             ProductName  correlation
# 2471                      PARTY BUNTING         1.00
# 3524                     SPOTTY BUNTING         0.25
# 3301  SET/20 FRUIT SALAD PAPER NAPKINS          0.21
# 726           CHARLOTTE BAG SUKI DESIGN         0.18
# 120           75 GREEN FAIRY CAKE CASES         0.18

# %%
recommendations = get_recommendations(df_items, '75 GREEN FAIRY CAKE CASES')
recommendations.head()
# Out:
#                             ProductName  correlation
# 120           75 GREEN FAIRY CAKE CASES         1.00
# 3301  SET/20 FRUIT SALAD PAPER NAPKINS          0.31
# 726           CHARLOTTE BAG SUKI DESIGN         0.27
# 2878    RED RETROSPOT OVEN GLOVE DOUBLE         0.23
# 836        CITRONELLA CANDLE GARDEN POT         0.21

# %%
recommendations = get_recommendations(df_items,'CITRONELLA CANDLE GARDEN POT')
recommendations.head()
# Out:
#                           ProductName  correlation
# 836      CITRONELLA CANDLE GARDEN POT         1.00
# 572           BOX OF 9 PEBBLE CANDLES         0.36
# 120         75 GREEN FAIRY CAKE CASES         0.21
# 2878  RED RETROSPOT OVEN GLOVE DOUBLE         0.14
# 835       CITRONELLA CANDLE FLOWERPOT         0.14

# %%
recommendations = get_recommendations(df_items,'DOORMAT FAIRY CAKE')
recommendations.head(10)
# Out:
#                              ProductName  correlation
# 1072                  DOORMAT FAIRY CAKE         1.00
# 3630                TEA TIME TEA TOWELS          0.72
# 1241  FAIRY CAKE FLANNEL ASSORTED COLOUR         0.58
# 1478         GIN + TONIC DIET METAL SIGN         0.58
# 3627              TEA TIME PARTY BUNTING         0.50
# 3918  WHITE HANGING HEART T-LIGHT HOLDER         0.48
# 1088                  DOORMAT UNION FLAG         0.46
# 1075                      DOORMAT HEARTS         0.41
# 1082                 DOORMAT NEW ENGLAND         0.41
# 1087                     DOORMAT TOPIARY         0.37
